# %%
import pandas as pd
import numpy as np


# Input data files are available in the read-only 
import os
for dirname, _, filenames in os.walk('D:\Data Science With Scikitlearn and Tensorflow\Titatnic-dataset-model'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# D:\Data Science With Scikitlearn and Tensorflow\Titatnic-dataset-model\practice_1.ipynb
# D:\Data Science With Scikitlearn and Tensorflow\Titatnic-dataset-model\titanic_dataset.ipynb
# D:\Data Science With Scikitlearn and Tensorflow\Titatnic-dataset-model\titianic_model_2.ipynb
# D:\Data Science With Scikitlearn and Tensorflow\Titatnic-dataset-model\datasets\gender_submission.csv
# D:\Data Science With Scikitlearn and Tensorflow\Titatnic-dataset-model\datasets\test.csv
# D:\Data Science With Scikitlearn and Tensorflow\Titatnic-dataset-model\datasets\train.csv

# %%
train_data = pd.read_csv("datasets/train.csv")
print("Train data is imported")
print("-"*50)

test_data = pd.read_csv("datasets/test.csv")
print("Test data is imported")
# Out:
# Train data is imported
# --------------------------------------------------
# Test data is imported

# %%
all_data = pd.concat([train_data,test_data])

# %%
all_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pclass_data = all_data.loc[:,['Pclass','Sex']]
# pclass_data = all_data['Pclass']

# %%
from sklearn.preprocessing import LabelBinarizer

encoder = LabelBinarizer()

# %%
pclass_data
# Out:
#      Pclass     Sex
# 0         3    male
# 1         1  female
# 2         3  female
# 3         1  female
# 4         3    male
# ..      ...     ...
# 413       3    male
# 414       1  female
# 415       3    male
# 416       3    male
# 417       3    male
#
# [1309 rows x 2 columns]

# %%
pclass_data[["Pclass","Sex"]] = pclass_data[["Pclass","Sex"]].apply(LabelBinarizer().fit_transform)
pclass_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Data Science With Scikitlearn and Tensorflow\Titatnic-dataset-model\practice_1.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Data%20Science%20With%20Scikitlearn%20and%20Tensorflow/Titatnic-dataset-model/practice_1.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> pclass_data[["Pclass","Sex"]] = pclass_data[["Pclass","Sex"]].apply(LabelBinarizer().fit_transform)
#       <a href='vscode-notebook-cell:/d%3A/Data%20Science%20With%20Scikitlearn%20and%20Tensorflow/Titatnic-dataset-model/practice_1.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> pclass_data
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:8839, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8828 from pandas.core.apply import frame_apply
#    8830 op = frame_apply(
# ...

# %%
from sklearn.preprocessing import LabelBinarizer

encoder = LabelBinarizer()
one_hot_encoded_data = encoder.fit_transform(pclass_data)
one_hot_encoded_data
# Out:
# array([[1],
#        [0],
#        [0],
#        ...,
#        [1],
#        [1],
#        [1]])
