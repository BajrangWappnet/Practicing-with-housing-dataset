# %%
import pandas as pd
import numpy as np


# Input data files are available in the read-only 
import os
for dirname, _, filenames in os.walk('D:\Data Science With Scikitlearn and Tensorflow\Titatnic-dataset-model'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# D:\Data Science With Scikitlearn and Tensorflow\Titatnic-dataset-model\titanic_dataset.ipynb
# D:\Data Science With Scikitlearn and Tensorflow\Titatnic-dataset-model\datasets\gender_submission.csv
# D:\Data Science With Scikitlearn and Tensorflow\Titatnic-dataset-model\datasets\test.csv
# D:\Data Science With Scikitlearn and Tensorflow\Titatnic-dataset-model\datasets\train.csv

# %%
train_data = pd.read_csv("datasets/train.csv")
print("Train data is imported")
print("-"*50)

test_data = pd.read_csv("datasets/test.csv")
print("Test data is imported")
# Out:
# Train data is imported
# --------------------------------------------------
# Test data is imported

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test_data['Survived']= -1

# %%
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Survived
# 0  34.5      0      0   330911   7.8292   NaN        Q        -1
# 1  47.0      1      0   363272   7.0000   NaN        S        -1
# 2  62.0      0      0   240276   9.6875   NaN        Q        -1
# 3  27.0      0      0   315154   8.6625   NaN        S        -1
# 4  22.0      1      1  3101298  12.2875   NaN        S        -1

# %%
all_data = pd.concat([train_data,test_data])

# %%
all_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 413         1305        -1       3
# 414         1306        -1       1
# 415         1307        -1       3
# 416         1308        -1       3
# 417         1309        -1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
all_data.isna().sum()
# Out:
# PassengerId       0
# Survived          0
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
all_data.shape
# Out:
# (1309, 12)

# %%
all_data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
all_1 = all_data.drop(columns=["Name", "Ticket", "Cabin"])

# %%
all_1
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch      Fare  \
# 0              1         0       3    male  22.0      1      0    7.2500
# 1              2         1       1  female  38.0      1      0   71.2833
# 2              3         1       3  female  26.0      0      0    7.9250
# 3              4         1       1  female  35.0      1      0   53.1000
# 4              5         0       3    male  35.0      0      0    8.0500
# ..           ...       ...     ...     ...   ...    ...    ...       ...
# 413         1305        -1       3    male   NaN      0      0    8.0500
# 414         1306        -1       1  female  39.0      0      0  108.9000
# 415         1307        -1       3    male  38.5      0      0    7.2500
# 416         1308        -1       3    male   NaN      0      0    8.0500
# 417         1309        -1       3    male   NaN      1      1   22.3583
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ...

# %%
all_data.keys()
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
all_1["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
all_2 = all_1.copy()
all_2 = all_2.drop(columns=['PassengerId', 'Survived', 'Pclass',  'Sex', 'Age', 'SibSp',
       'Parch',  'Fare'])

# %%
all_2.dtypes
# Out:
# Embarked    object
# dtype: object

# %%
all_1["Embarked"].isnull().sum()
# Out:
# 2

# %%
print(all_2.columns)
# Out:
# Index(['Embarked'], dtype='object')

# %%
from sklearn.preprocessing import LabelBinarizer

encoder = LabelBinarizer()
all_2['Embarked'] = encoder.fit_transform(all_2['Embarked'])
all_2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Data Science With Scikitlearn and Tensorflow\Titatnic-dataset-model\titanic_dataset.ipynb Cell 18 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/d%3A/Data%20Science%20With%20Scikitlearn%20and%20Tensorflow/Titatnic-dataset-model/titanic_dataset.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> from sklearn.preprocessing import LabelBinarizer
#       <a href='vscode-notebook-cell:/d%3A/Data%20Science%20With%20Scikitlearn%20and%20Tensorflow/Titatnic-dataset-model/titanic_dataset.ipynb#X21sZmlsZQ%3D%3D?line=2'>3</a> encoder = LabelBinarizer()
# ----> <a href='vscode-notebook-cell:/d%3A/Data%20Science%20With%20Scikitlearn%20and%20Tensorflow/Titatnic-dataset-model/titanic_dataset.ipynb#X21sZmlsZQ%3D%3D?line=3'>4</a> all_2['Embarked'] = encoder.fit_transform(all_2['Embarked'])
# ...

# %%
all_3 = pd.DataFrame(all_2, columns=all_1["Embarked"].unique())

# %%
all_3.head()
# Out:
#     S   C   Q  NaN
# 0 NaN NaN NaN  NaN
# 1 NaN NaN NaN  NaN
# 2 NaN NaN NaN  NaN
# 3 NaN NaN NaN  NaN
# 4 NaN NaN NaN  NaN

# %%
all_3.columns
# Out:
# Index(['S', 'C', 'Q', nan], dtype='object')

# %%
all_3 = all_3.drop(columns=np.nan)

# %%
all_3.head()
# Out:
#    S  C  Q
# 0  0  0  1
# 1  1  0  0
# 2  0  0  1
# 3  0  0  1
# 4  0  0  1
